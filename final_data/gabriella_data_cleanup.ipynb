# %%
import pandas as pd
import numpy as np

# load files
file_to_load = "movie_budget.csv"
inflation = "inflation.csv"

# %%
# Read Purchasing File and store into Pandas data frame
raw_data = pd.read_csv(file_to_load)
raw_data
# Out:
#        movie_id                        title  year  \
# 0     tt0099088  Back to the Future Part III  1990
# 1     tt0099165  The Bonfire of the Vanities  1990
# 2     tt0099348           Dances with Wolves  1990
# 3     tt0099422                   Dick Tracy  1990
# 4     tt0099423                   Die Hard 2  1990
# ...         ...                          ...   ...
# 3238  tt8772262                    Midsommar  2019
# 3239  tt8946378                   Knives Out  2019
# 3240  tt9024106                    Unplanned  2019
# 3241  tt9134216            Playing with Fire  2019
# 3242  tt9173418           Brahms: The Boy II  2020
#
#                                                  trivia   mpaa release_date  \
# 0     Stranded in 1955, Marty McFly learns about the...    NaN       25-May
# 1     After his mistress runs over a young teen, a W...      R       22-Dec
# 2     Lieutenant John Dunbar, assigned to a remote w...    NaN        9-Nov
# 3     The comic strip detective finds his life vastl...    NaN       15-Jun
# 4     John McClane attempts to avert disaster as rog...    NaN        6-Jul
# ...                                                 ...    ...          ...
# 3238  A couple travels to Sweden to visit a rural ho...      R        3-Jul
# 3239  A detective investigates the death of a patria...  PG-13       21-Nov
# 3240  All Abby Johnson ever wanted to do was help wo...      R       29-Mar
# 3241  A crew of rugged firefighters meet their match...     PG        7-Nov
# 3242  After a family moves into the Heelshire Mansio...  PG-13       20-Feb
#
#          run_time                          distributor            director  \
# 0     1 hr 58 min                   Universal Pictures     Robert Zemeckis
# 1      2 hr 5 min                         Warner Bros.      Brian De Palma
# 2      3 hr 1 min                       Orion Pictures       Kevin Costner
# 3     1 hr 45 min  Walt Disney Studios Motion Pictures       Warren Beatty
# 4      2 hr 4 min                Twentieth Century Fox        Renny Harlin
# ...           ...                                  ...                 ...
# 3238  2 hr 28 min                                  A24           Ari Aster
# 3239  2 hr 11 min                            Lionsgate        Rian Johnson
# 3240  1 hr 49 min              Pure Flix Entertainment     Chuck Konzelman
# 3241  1 hr 36 min                   Paramount Pictures        Andy Fickman
# 3242  1 hr 26 min                    STX Entertainment  William Brent Bell
#
#                  writer  ...            main_actor_4    budget     domestic  \
# 0       Robert Zemeckis  ...        Thomas F. Wilson  40000000   88277583.0
# 1     Michael Cristofer  ...            Kim Cattrall  47000000   15691192.0
# 2         Michael Blake  ...         Rodney A. Grant  22000000  184208848.0
# 3         Chester Gould  ...          Charlie Korsmo  47000000  103738726.0
# 4          Walter Wager  ...     Reginald VelJohnson  70000000  117540947.0
# ...                 ...  ...                     ...       ...          ...
# 3238          Ari Aster  ...  William Jackson Harper   9000000   27426361.0
# 3239       Rian Johnson  ...        Jamie Lee Curtis  40000000  165363234.0
# 3240       Abby Johnson  ...              Jared Lotz   6000000   19005109.0
# 3241           Dan Ewen  ...              Tyler Mane  29900000   44451847.0
# 3242      Stacey Menear  ...            Ralph Ineson  10000000   12611536.0
#
#      international    worldwide    genre_1   genre_2  genre_3   genre_4  \
# 0      157866667.0  246144250.0  Adventure    Comedy   Sci-Fi   Western
# 1              NaN   15691192.0     Comedy     Drama  Romance       NaN
# 2      240000000.0  424208848.0  Adventure     Drama  Western       NaN
# 3       59000000.0  162738726.0     Action    Comedy    Crime     Music
# 4      122706486.0  240247433.0     Action  Thriller      NaN       NaN
# ...            ...          ...        ...       ...      ...       ...
# 3238    19463936.0   46890297.0      Drama    Horror  Mystery  Thriller
# 3239   143869563.0  309232797.0     Comedy     Crime    Drama   Mystery
# 3240     2046806.0   21051915.0  Biography     Drama      NaN       NaN
# 3241    24179822.0   68631669.0     Comedy    Family      NaN       NaN
# 3242     7700000.0   20311536.0      Drama    Horror  Mystery  Thriller
#
#                                                    html
# 0     https://www.boxofficemojo.com/title/tt0099088/...
# 1     https://www.boxofficemojo.com/title/tt0099165/...
# 2     https://www.boxofficemojo.com/title/tt0099348/...
# 3     https://www.boxofficemojo.com/title/tt0099422/...
# 4     https://www.boxofficemojo.com/title/tt0099423/...
# ...                                                 ...
# 3238  https://www.boxofficemojo.com/title/tt8772262/...
# 3239  https://www.boxofficemojo.com/title/tt8946378/...
# 3240  https://www.boxofficemojo.com/title/tt9024106/...
# 3241  https://www.boxofficemojo.com/title/tt9134216/...
# 3242  https://www.boxofficemojo.com/title/tt9173418/...
#
# [3243 rows x 26 columns]

# %%
clean_data = raw_data[['title', 'year', 'release_date', 'mpaa', 'writer', 'composer', 'cinematographer', 'main_actor_1', 'main_actor_2', 'main_actor_3', 'main_actor_4', 'budget','domestic', 'international', 'worldwide', 'genre_1', 'genre_2', 'genre_3', 'genre_4']]
clean_data.head()
# Out:
#                          title  year release_date mpaa             writer  \
# 0  Back to the Future Part III  1990       25-May  NaN    Robert Zemeckis
# 1  The Bonfire of the Vanities  1990       22-Dec    R  Michael Cristofer
# 2           Dances with Wolves  1990        9-Nov  NaN      Michael Blake
# 3                   Dick Tracy  1990       15-Jun  NaN      Chester Gould
# 4                   Die Hard 2  1990        6-Jul  NaN       Walter Wager
#
#          composer   cinematographer    main_actor_1       main_actor_2  \
# 0  Alan Silvestri       Dean Cundey  Michael J. Fox  Christopher Lloyd
# 1     Dave Grusin   Vilmos Zsigmond       Tom Hanks       Bruce Willis
# 2      John Barry       Dean Semler   Kevin Costner     Mary McDonnell
# 3    Danny Elfman  Vittorio Storaro   Warren Beatty            Madonna
# 4   Michael Kamen       Oliver Wood    Bruce Willis   William Atherton
#
#        main_actor_3         main_actor_4    budget     domestic  \
# 0  Mary Steenburgen     Thomas F. Wilson  40000000   88277583.0
# 1  Melanie Griffith         Kim Cattrall  47000000   15691192.0
# 2     Graham Greene      Rodney A. Grant  22000000  184208848.0
# 3         Al Pacino       Charlie Korsmo  47000000  103738726.0
# 4    Bonnie Bedelia  Reginald VelJohnson  70000000  117540947.0
#
#    international    worldwide    genre_1   genre_2  genre_3  genre_4
# 0    157866667.0  246144250.0  Adventure    Comedy   Sci-Fi  Western
# 1            NaN   15691192.0     Comedy     Drama  Romance      NaN
# 2    240000000.0  424208848.0  Adventure     Drama  Western      NaN
# 3     59000000.0  162738726.0     Action    Comedy    Crime    Music
# 4    122706486.0  240247433.0     Action  Thriller      NaN      NaN

# %%
movie_data = clean_data.dropna()
movie_data.dtypes
# Out:
# title               object
# year                 int64
# release_date        object
# mpaa                object
# writer              object
# composer            object
# cinematographer     object
# main_actor_1        object
# main_actor_2        object
# main_actor_3        object
# main_actor_4        object
# budget               int64
# domestic           float64
# international      float64
# worldwide          float64
# genre_1             object
# genre_2             object
# genre_3             object
# genre_4             object
# dtype: object

# %%
inflation_mult = pd.read_csv(inflation)
inflation_mult

inflation_mult["Multiplier"]=inflation_mult["Multiplier"] +1
inflation_mult
# Out:
#     year  Multiplier
# 0   1990        1.98
# 1   1991        1.90
# 2   1992        1.84
# 3   1993        1.79
# 4   1994        1.75
# 5   1995        1.70
# 6   1996        1.65
# 7   1997        1.61
# 8   1998        1.59
# 9   1999        1.55
# 10  2000        1.50
# 11  2001        1.46
# 12  2002        1.44
# 13  2003        1.41
# 14  2004        1.37
# 15  2005        1.33
# 16  2006        1.28
# 17  2007        1.25
# 18  2008        1.20
# 19  2009        1.21
# 20  2010        1.19
# 21  2011        1.15
# 22  2012        1.13
# 23  2013        1.11
# 24  2014        1.09
# 25  2015        1.09
# 26  2016        1.08
# 27  2017        1.06
# 28  2018        1.03
# 29  2019        1.01

# %%
#inflation_clean = inflation_mult.dropna(axis=1)
#inflation_clean

inflation_clean = inflation_mult[["year", "Multiplier"]]
inflation_clean

inflation_cleaner = inflation_clean.dropna()
inflation_cleaner



#inflation_cleaner - use tonumeric, if it's a string that can't be converted, use string.replace to replace a pe
# Out:
#     year  Multiplier
# 0   1990        1.98
# 1   1991        1.90
# 2   1992        1.84
# 3   1993        1.79
# 4   1994        1.75
# 5   1995        1.70
# 6   1996        1.65
# 7   1997        1.61
# 8   1998        1.59
# 9   1999        1.55
# 10  2000        1.50
# 11  2001        1.46
# 12  2002        1.44
# 13  2003        1.41
# 14  2004        1.37
# 15  2005        1.33
# 16  2006        1.28
# 17  2007        1.25
# 18  2008        1.20
# 19  2009        1.21
# 20  2010        1.19
# 21  2011        1.15
# 22  2012        1.13
# 23  2013        1.11
# 24  2014        1.09
# 25  2015        1.09
# 26  2016        1.08
# 27  2017        1.06
# 28  2018        1.03
# 29  2019        1.01

# %%
#empty lists
titles = []

budgets = []
adjusted_budgets = []

domestics = []
adjusted_domestics = []

internationals = []
adjusted_internationals = []

worldwides = []
adjusted_worldwides = []

#budget
i = 0

for year in inflation_cleaner["year"]:
    year_movie = movie_data.loc[movie_data["year"] == year,:]
    for budget in year_movie['budget']:
        adjusted_budget=budget*inflation_cleaner.iloc[i,1]
        budgets.append(budget)
        adjusted_budgets.append(adjusted_budget)
    i+=1
#domestic
i = 0

for year in inflation_cleaner["year"]:
    year_movie = movie_data.loc[movie_data["year"] == year,:]
    for domestic in year_movie['domestic']:
        adjusted_domestic=domestic*inflation_cleaner.iloc[i,1]
        domestics.append(domestic)
        adjusted_domestics.append(adjusted_domestic)
    i+=1
#international
i=0

for year in inflation_cleaner["year"]:
    year_movie = movie_data.loc[movie_data["year"] == year,:]
    for international in year_movie['international']:
        adjusted_international=international*inflation_cleaner.iloc[i,1]
        internationals.append(international)
        adjusted_internationals.append(adjusted_international)
    i+=1

#worldwide
i=0 
for year in inflation_cleaner["year"]:
    year_movie = movie_data.loc[movie_data["year"] == year,:]
    for worldwide in year_movie['worldwide']:
        adjusted_worldwide=worldwide*inflation_cleaner.iloc[i,1]
        worldwides.append(worldwide)
        adjusted_worldwides.append(adjusted_worldwide)
    i+=1
i=0
for year in inflation_cleaner["year"]:
    year_movie = movie_data.loc[movie_data["year"] == year,:]
    for title in year_movie['title']:
        titles.append(title)
        

#if movie_data.loc["year"] in inflation_cleaner.loc["year"]
       # multiplier = inflation_cleaner[row.loc["year"]]
            #print(year_movie[f'{movie}'])
print(adjusted_worldwides)
# Out:
# [48056968.08, 59559592.599999994, 253522265.6, 243689726.95999998, 277192710.77, 316824930.72, 1847316732.5900002, 245764295.31, 208615730.75, 377803504.75, 196011018.0, 615270962.25, 332208374.75, 206624468.75, 174005625.5, 18780965.9, 240391940.79999998, 362467567.2, 192938917.7, 446797298.0, 556467050.3, 232727845.35, 77990551.64999999, 147603655.65, 18374074.95, 68624961.89999999, 275503729.69, 226700150.67, 395538595.05999994, 280885843.77, 256521750.79999998, 948918767.79, 264857986.26, 195155146.97, 197745783.48, 880398562.92, 216493482.57, 397958751.57, 389106491.76, 179014376.22, 321645714.17999995, 460015292.46, 56498640.800000004, 167015655.8, 47519673.7, 48715461.5, 444542129.7, 250520487.55, 35726869.15, 344262255.55, 1591978195.8500001, 62407681.0, 35927798.75, 51864567.050000004, 329226813.8, 84155961.95, 208324823.6, 37965081.550000004, 232044070.6, 483626238.40000004, 234815165.25, 328583016.65000004, 255204620.1, 275654414.90000004, 103813291.35000001, 18272447.8, 465209818.85, 5154890.8, 274832284.05, 182525675.0, 20032297.650000002, 524734147.5, 52702230.0, 9930363.0, 1386054.0, 4504944.0, 23765412.0, 70689442.5, 53321641.5, 89202412.5, 60600637.5, 396158317.5, 437130526.5, 216085309.5, 60664515.0, 285320182.5, 21600490.5, 44047483.5, 493077651.0, 71075533.5, 48253455.0, 148911700.5, 102159367.5, 322941513.0, 320288604.0, 323495788.5, 41948797.5, 76203180.0, 170874711.0, 19801458.0, 70901743.5, 29119489.5, 23207953.5, 319114080.0, 144128215.5, 372177181.5, 187117624.5, 90155520.0, 71605641.0, 102616912.5, 24964786.5, 1296235925.96, 528829140.4, 401066876.4, 133959674.92, 12693707.2, 538419981.14, 124292471.8, 82285570.8, 1159942.26, 1115060.4, 647190119.84, 24933707.72, 655862579.6999999, 51687387.199999996, 98742578.38, 34484629.14, 215983902.79999998, 18807143.3, 27331455.5, 3700183.12, 28867772.62, 215853748.18, 103299239.84, 42952164.86, 90684826.7, 293003738.32, 10189475.78, 14646032.34, 62864025.92, 177036.68, 3358998.64, 41625551.92, 42897207.54, 205961995.6, 296946977.86, 507095670.92, 94079256.62, 640994814.72, 941443156.8, 158459562.72, 55862327.519999996, 9550631.52, 279246775.68, 516057013.44, 223214446.07999998, 43031008.8, 244737800.64, 108568869.11999999, 172904510.88, 118296263.52, 96964516.8, 91845806.39999999, 39850738.559999995, 75345696.0, 79639601.75999999, 12071430.719999999, 17715195.36, 94631221.44, 396937012.32, 42734452.32, 47539879.199999996, 66048959.519999996, 18192595.68, 260108506.07999998, 166139877.6, 37881407.519999996, 19316759.04, 95329126.08, 21522456.0, 165650529.6, 8290000.8, 587877000.48, 995752.7999999999, 172401635.51999998, 123437354.39999999, 23654118.24, 2074540.3199999998, 427591873.44, 1266430455.36, 62511841.44, 40775689.44, 73996526.88, 82927418.39999999, 47638869.12, 43203971.519999996, 29023054.56, 89675683.2, 45784393.92, 243949047.69, 385408773.96, 47900607.419999994, 53176569.39, 292893150.99, 62534805.66, 64947204.269999996, 18222749.759999998, 66958835.76, 114548972.46, 71532315.99, 16504052.819999998, 103633041.50999999, 61949425.83, 365437861.08, 79650276.78, 78303581.55, 12076066.26, 298387774.34999996, 100683267.92999999, 252763937.64, 188884362.81, 13309920.6, 78248743.83, 82902097.74, 121920108.41999999, 96297773.13, 171984765.51, 96605930.03999999, 173737977.84, 312557199.93, 226793328.11999997, 64141768.559999995, 220799219.30999997, 114184498.74, 72111149.19, 7297053.149999999, 257029275.05999997, 165321030.78, 277913365.97999996, 82441586.1, 77103716.67, 136149209.45000002, 38748582.690000005, 158783731.58, 1090648508.74, 56107806.11000001, 97619354.11000001, 148015652.14000002, 177199593.53, 35373346.57, 757116212.2700001, 15640022.750000002, 141617073.99, 98885086.15, 37522610.79000001, 179243747.24, 74939143.85000001, 41265319.27, 32777924.040000003, 23223831.740000002, 289711481.95000005, 483793440.26000005, 95111412.93, 193261963.99, 79387439.32000001, 229198523.04000002, 14892171.260000002, 278887964.09000003, 161102178.47, 278346211.29 ...

# %%
adjusted_df = pd.DataFrame({"Title":titles, 
                             "Adjusted Budget":adjusted_budgets, 
                             "Adjusted Domestic":adjusted_domestics, 
                             "Adjusted International":adjusted_internationals, 
                             "Adjusted Worldwide":adjusted_worldwides})
adjusted_df.head()
# Out:
#                          Title  Adjusted Budget  Adjusted Domestic  \
# 0                    Lionheart       11880000.0       4.767483e+07
# 1  The People Under the Stairs       11400000.0       4.598789e+07
# 2                 Far and Away      110400000.0       1.083463e+08
# 3        A League of Their Own       73600000.0       1.978624e+08
# 4                Cool Runnings       25060000.0       1.232527e+08
#
#    Adjusted International  Adjusted Worldwide
# 0            3.821400e+05        4.805697e+07
# 1            1.357170e+07        5.955959e+07
# 2            1.451760e+08        2.535223e+08
# 3            4.582730e+07        2.436897e+08
# 4            1.539400e+08        2.771927e+08

# %%
#if loc["year"] = 1990:
#if the value of the year column = the key of the inflation multiplier dictionary, then multiply the value in column ""
#budget" "domestic", "international", "worldwide" by the value in the dictionary

#other option: instead of having a multiplier column, create a dictionary of inflation 
#use loc to locate (one is index) to locate specific values in a column 
#for loop if 

#for row in movie_data:
  # if row.loc["year"] in inflation_cleaner.loc["year"]
       # multiplier = inflation_cleaner[row.loc["year"]]

# %%
movie_data.head()
# Out:
#                            title  year release_date   mpaa        writer  \
# 13                     Lionheart  1990       11-Jan      R   S.N. Warren
# 74                  Far and Away  1992       22-May  PG-13    Bob Dolman
# 79         A League of Their Own  1992        1-Jul     PG    Kim Wilson
# 86   The People Under the Stairs  1991        1-Nov      R    Wes Craven
# 100                Cool Runnings  1993        1-Oct     PG  Lynn Siefert
#
#           composer     cinematographer           main_actor_1    main_actor_2  \
# 13      John Scott       Robert C. New  Jean-Claude Van Damme   Harrison Page
# 74   John Williams      Mikael Salomon             Tom Cruise   Nicole Kidman
# 79     Hans Zimmer   Miroslav Ondrícek              Tom Hanks     Geena Davis
# 86       Don Peake        Sandi Sissel  Brandon Quintin Adams  Everett McGill
# 100    Hans Zimmer  Phedon Papamichael             John Candy            Leon
#
#         main_actor_3    main_actor_4    budget     domestic  international  \
# 13   Deborah Rennard    Lisa Pelikan   6000000   24078196.0       193000.0
# 74     Thomas Gibson   Robert Prosky  60000000   58883840.0     78900000.0
# 79        Lori Petty         Madonna  40000000  107533928.0     24906141.0
# 86       Wendy Robie     A.J. Langer   6000000   24204154.0      7143000.0
# 100     Doug E. Doug  Rawle D. Lewis  14000000   68856263.0     86000000.0
#
#        worldwide    genre_1 genre_2  genre_3   genre_4
# 13    24271196.0     Action   Crime    Drama     Sport
# 74   137783840.0  Adventure   Drama  Romance   Western
# 79   132440069.0     Comedy   Drama   Family     Sport
# 86    31347154.0     Comedy  Horror  Mystery  Thriller
# 100  154856263.0  Adventure  Comedy   Family   History

# %%
genre2 = clean_data.groupby("genre_2").sum()
genre3 = clean_data.groupby("genre_3").sum()
genre4 = clean_data.groupby("genre_4").sum()

# %%
add1 = genre_df.add(genre2, fill_value=0)
add2 = add1.add(genre3, fill_value=0) 
add3 = add2.add(genre4, fill_value=0)
add3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gr/g0lzn1p15gqfb11105yyt_tm0000gn/T/ipykernel_8740/1366581112.py in <module>
# ----> 1 add1 = genre_df.add(genre2, fill_value=0)
#       2 add2 = add1.add(genre3, fill_value=0)
#       3 add3 = add2.add(genre4, fill_value=0)
#       4 add3
#
# NameError: name 'genre_df' is not defined

# %%
genre = movie_data.groupby("genre_1")
sumgenre = genre.sum()
genre_df = pd.DataFrame(sumgenre)
genre_df.reset_index()

genre_df.plot.bar(y="domestic")
add3.plot.bar(y="domestic")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/gr/g0lzn1p15gqfb11105yyt_tm0000gn/T/ipykernel_8740/3830425719.py in <module>
#       5
#       6 genre_df.plot.bar(y="domestic")
# ----> 7 add3.plot.bar(y="domestic")
#
# NameError: name 'add3' is not defined
