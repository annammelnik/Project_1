# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path1 = "Mojo_budget_update.csv"
path2 = "adjusted_for_inflation.csv"
moviesdf = pd.read_csv(path1)
adjusteddf = pd.read_csv(path2)
moviesdf = moviesdf[['title','director','writer','producer','main_actor_1','main_actor_2','main_actor_3','main_actor_4']]
merged = pd.merge(moviesdf, adjusteddf, on ='title')
merged
# Out:
#                              title              director         writer  \
# 0          The Godfather: Part III  Francis Ford Coppola     Mario Puzo
# 1                           Havana        Sydney Pollack  Judith Rascoe
# 2                        Lionheart       Sheldon Lettich    S.N. Warren
# 3                     Pretty Woman        Garry Marshall    J.F. Lawton
# 4     Teenage Mutant Ninja Turtles          Steve Barron  Kevin Eastman
# ...                            ...                   ...            ...
# 2379                    21 Bridges            Brian Kirk    Adam Mervis
# 2380                     Midsommar             Ari Aster      Ari Aster
# 2381                    Knives Out          Rian Johnson   Rian Johnson
# 2382                     Unplanned       Chuck Konzelman   Abby Johnson
# 2383             Playing with Fire          Andy Fickman       Dan Ewen
#
#                   producer           main_actor_1        main_actor_2  \
# 0     Francis Ford Coppola              Al Pacino        Diane Keaton
# 1           Sydney Pollack         Robert Redford           Lena Olin
# 2              Eric Karson  Jean-Claude Van Damme       Harrison Page
# 3            Arnon Milchan           Richard Gere       Julia Roberts
# 4               David Chan            Judith Hoag        Elias Koteas
# ...                    ...                    ...                 ...
# 2379      Chadwick Boseman       Chadwick Boseman       Sienna Miller
# 2380      Patrik Andersson          Florence Pugh         Jack Reynor
# 2381           Ram Bergman           Daniel Craig         Chris Evans
# 2382           Chris Jones        Ashley Bratcher         Brooks Ryan
# 2383           Todd Garner              John Cena  Keegan-Michael Key
#
#           main_actor_3            main_actor_4  Adjusted Budget  \
# 0          Andy Garcia             Talia Shire       52920000.0
# 1           Alan Arkin            Tomas Milian       39200000.0
# 2      Deborah Rennard            Lisa Pelikan        5880000.0
# 3      Jason Alexander       Laura San Giacomo       13720000.0
# 4            Josh Pais            David Forman       11250000.0
# ...                ...                     ...              ...
# 2379      J.K. Simmons           Stephan James         330000.0
# 2380  Vilhelm Blomgren  William Jackson Harper          90000.0
# 2381      Ana de Armas        Jamie Lee Curtis         400000.0
# 2382       Robia Scott              Jared Lotz          60000.0
# 2383    John Leguizamo              Tyler Mane         299000.0
#
#       Adjusted Domestic  Adjusted International  Adjusted Worldwide
# 0          6.533274e+07            6.869800e+07        1.340307e+08
# 1          9.058277e+06            3.942540e+05        9.452531e+06
# 2          2.359663e+07            1.891400e+05        2.378577e+07
# 3          1.748381e+08            2.793000e+08        4.541381e+08
# 4          1.720843e+07            2.644200e+07        4.365043e+07
# ...                 ...                     ...                 ...
# 2379       2.853976e+05            2.140000e+05        4.993976e+05
# 2380       2.742636e+05            1.946394e+05        4.689030e+05
# 2381       1.653632e+06            1.438696e+06        3.092328e+06
# 2382       1.900511e+05            2.046806e+04        2.105191e+05
# 2383       4.445185e+05            2.417982e+05        6.863167e+05
#
# [2384 rows x 12 columns]

# %%
num_of_movies = merged.groupby('main_actor_1').count().sort_values('title', ascending=False)['title']
total_revenue1 = merged.groupby('main_actor_1').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue1['Number of movies'] = num_of_movies
total_revenue1.head(20)
# Out:
#                        Adjusted Domestic  Adjusted International  \
# main_actor_1
# Tom Cruise                  9.440696e+08            1.529444e+09
# Tom Hanks                   1.063223e+09            1.174171e+09
# Leonardo DiCaprio           7.259783e+08            1.429278e+09
# Will Smith                  8.046000e+08            1.058430e+09
# Daniel Radcliffe            5.866999e+08            1.272254e+09
# Arnold Schwarzenegger       6.832387e+08            1.094294e+09
# Johnny Depp                 6.559404e+08            1.037005e+09
# Bruce Willis                6.261194e+08            9.793752e+08
# Elijah Wood                 5.128976e+08            9.001309e+08
# Keanu Reeves                4.693713e+08            7.700493e+08
# Mel Gibson                  5.872831e+08            6.300405e+08
# Jim Carrey                  5.514985e+08            5.354743e+08
# Tobey Maguire               5.063579e+08            5.112232e+08
# Harrison Ford               4.922624e+08            5.214782e+08
# Sam Neill                   4.015733e+08            5.833621e+08
# Nicolas Cage                4.193295e+08            4.887952e+08
# Julia Roberts               4.582796e+08            4.359105e+08
# Robert Downey Jr.           3.676451e+08            5.163722e+08
# Brad Pitt                   3.324913e+08            5.510505e+08
# Vin Diesel                  3.489057e+08            5.219750e+08
#
#                        Adjusted Worldwide  Number of movies
# main_actor_1
# Tom Cruise                   2.473513e+09                24
# Tom Hanks                    2.237394e+09                20
# Leonardo DiCaprio            2.155256e+09                13
# Will Smith                   1.863030e+09                19
# Daniel Radcliffe             1.858954e+09                 6
# Arnold Schwarzenegger        1.777533e+09                14
# Johnny Depp                  1.692945e+09                21
# Bruce Willis                 1.605495e+09                19
# Elijah Wood                  1.413028e+09                 5
# Keanu Reeves                 1.239421e+09                13
# Mel Gibson                   1.217324e+09                 9
# Jim Carrey                   1.086973e+09                14
# Tobey Maguire                1.017581e+09                 6
# Harrison Ford                1.013741e+09                11
# Sam Neill                    9.849354e+08                 2
# Nicolas Cage                 9.081247e+08                21
# Julia Roberts                8.941901e+08                10
# Robert Downey Jr.            8.840173e+08                10
# Brad Pitt                    8.835418e+08                15
# Vin Diesel                   8.708807e+08                15

# %%
num_of_movies = merged.groupby('main_actor_2').count().sort_values('title', ascending=False)['title']
total_revenue2 = merged.groupby('main_actor_2').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue2['Number of movies'] = num_of_movies
total_revenue2.head(20)
# Out:
#                     Adjusted Domestic  Adjusted International  \
# main_actor_2
# Kate Winslet             4.778801e+08            1.035946e+09
# Kirsten Dunst            4.812157e+08            6.024823e+08
# Emma Watson              3.259825e+08            6.981462e+08
# Ian McKellen             3.170977e+08            5.773196e+08
# Rupert Grint             2.617984e+08            5.750868e+08
# Julia Roberts            3.264012e+08            5.100091e+08
# Laurence Fishburne       3.404039e+08            4.878065e+08
# Laura Dern               3.193108e+08            4.979933e+08
# Brad Pitt                2.557477e+08            4.666265e+08
# Natalie Portman          3.276580e+08            3.875581e+08
# Liam Neeson              3.028875e+08            3.949749e+08
# Bill Pullman             2.732237e+08            4.168056e+08
# Zoe Saldana              2.123934e+08            4.563486e+08
# Rachel Weisz             2.603823e+08            3.796209e+08
# Cameron Diaz             2.255506e+08            4.101766e+08
# Matt Damon               3.151810e+08            3.009638e+08
# Helen Hunt               3.055331e+08            2.997222e+08
# Julianne Moore           2.419034e+08            3.598594e+08
# Hugh Jackman             2.938513e+08            3.068347e+08
# Robin Wright             2.882663e+08            3.023154e+08
#
#                     Adjusted Worldwide  Number of movies
# main_actor_2
# Kate Winslet              1.513826e+09                 8
# Kirsten Dunst             1.083698e+09                 6
# Emma Watson               1.024129e+09                 5
# Ian McKellen              8.944173e+08                 4
# Rupert Grint              8.368852e+08                 2
# Julia Roberts             8.364104e+08                 8
# Laurence Fishburne        8.282104e+08                 7
# Laura Dern                8.173041e+08                 3
# Brad Pitt                 7.223742e+08                 5
# Natalie Portman           7.152161e+08                 7
# Liam Neeson               6.978624e+08                 3
# Bill Pullman              6.900292e+08                 3
# Zoe Saldana               6.687420e+08                 4
# Rachel Weisz              6.400033e+08                 9
# Cameron Diaz              6.357271e+08                 8
# Matt Damon                6.161448e+08                 9
# Helen Hunt                6.052553e+08                 5
# Julianne Moore            6.017628e+08                 8
# Hugh Jackman              6.006859e+08                 8
# Robin Wright              5.905817e+08                 3

# %%
num_of_movies = merged.groupby('main_actor_3').count().sort_values('title', ascending=False)['title']
total_revenue3 = merged.groupby('main_actor_3').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue3['Number of movies'] = num_of_movies
total_revenue3
# Out:
#                   Adjusted Domestic  Adjusted International  \
# main_actor_3
# Jeff Goldblum          5.623037e+08            8.796638e+08
# Billy Zane             4.022120e+08            9.363961e+08
# Rupert Grint           3.249222e+08            6.978104e+08
# Orlando Bloom          3.197202e+08            5.409727e+08
# Carrie-Anne Moss       2.901737e+08            4.789297e+08
# ...                             ...                     ...
# Richard Coyle          2.621850e+03            4.491975e+04
# Brad Renfro            1.531656e+04            2.484972e+04
# Aidan Quinn            2.801631e+04            5.552610e+03
# Mike White             2.387322e+04            1.010100e+03
# Lane Garrison          1.197180e+03            5.968980e+03
#
#                   Adjusted Worldwide  Number of movies
# main_actor_3
# Jeff Goldblum           1.441967e+09                 4
# Billy Zane              1.338608e+09                 1
# Rupert Grint            1.022733e+09                 5
# Orlando Bloom           8.606930e+08                 3
# Carrie-Anne Moss        7.691035e+08                 6
# ...                              ...               ...
# Richard Coyle           4.754160e+04                 1
# Brad Renfro             4.016628e+04                 1
# Aidan Quinn             3.356892e+04                 1
# Mike White              2.488332e+04                 1
# Lane Garrison           7.166160e+03                 1
#
# [1582 rows x 4 columns]

# %%
num_of_movies = merged.groupby('main_actor_4').count().sort_values('title', ascending=False)['title']
total_revenue4 = merged.groupby('main_actor_4').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue4['Number of movies'] = num_of_movies
total_revenue4
# Out:
#                       Adjusted Domestic  Adjusted International  \
# main_actor_4
# Kathy Bates                4.473792e+08            9.733624e+08
# Orlando Bloom              3.159930e+08            6.185403e+08
# Richard Attenborough       3.182342e+08            4.970620e+08
# Michelle Rodriguez         1.995219e+08            5.473854e+08
# Hugo Weaving               2.668790e+08            4.684282e+08
# ...                                 ...                     ...
# Billy Roche                2.801631e+04            5.552610e+03
# Sheila Kelley              1.188198e+04            1.598553e+04
# Gina Gershon               2.619815e+04            1.570160e+03
# John Baker                 2.387322e+04            1.010100e+03
# Tara Holt                  1.197180e+03            5.968980e+03
#
#                       Adjusted Worldwide  Number of movies
# main_actor_4
# Kathy Bates                 1.420742e+09                 5
# Orlando Bloom               9.345332e+08                 3
# Richard Attenborough        8.152962e+08                 1
# Michelle Rodriguez          7.469073e+08                 3
# Hugo Weaving                7.353072e+08                 3
# ...                                  ...               ...
# Billy Roche                 3.356892e+04                 1
# Sheila Kelley               2.786751e+04                 1
# Gina Gershon                2.776831e+04                 1
# John Baker                  2.488332e+04                 1
# Tara Holt                   7.166160e+03                 1
#
# [1799 rows x 4 columns]

# %%
# merge1 = pd.merge(total_revenue1, total_revenue2, left_index = True)
# merge1
add1 = total_revenue1.add(total_revenue2, fill_value=0)
add2 = add1.add(total_revenue3, fill_value=0) 
add3 = add2.add(total_revenue4, fill_value=0)
ww = add3.sort_values('Adjusted Worldwide', ascending = False).head(10)
ww.plot.bar()
# Out:
# <AxesSubplot:>
