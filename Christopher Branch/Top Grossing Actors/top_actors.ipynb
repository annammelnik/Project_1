# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path1 = "Mojo_budget_update.csv"
path2 = "adjusted_for_inflation.csv"
moviesdf = pd.read_csv(path1)
adjusteddf = pd.read_csv(path2)
moviesdf2 = moviesdf[['title','year','director','writer','producer','main_actor_1','main_actor_2','main_actor_3','main_actor_4']]
merged = pd.merge(moviesdf2, adjusteddf, on ='title')
merged = merged.loc[merged['year'] >=2010]
merged.sort_values('year')
# Out:
#                                          title  year           director  \
# 1621  Cats & Dogs: The Revenge of Kitty Galore  2010        Brad Peyton
# 1468                              TRON: Legacy  2010    Joseph Kosinski
# 1473                                Jackass 3D  2010      Jeff Tremaine
# 1474                            Blue Valentine  2010   Derek Cianfrance
# 1766                             Meek's Cutoff  2010    Kelly Reichardt
# ...                                        ...   ...                ...
# 2196                                     Dumbo  2019         Tim Burton
# 2184            Godzilla: King of the Monsters  2019  Michael Dougherty
# 2287                             The Good Liar  2019        Bill Condon
# 2383                         Playing with Fire  2019       Andy Fickman
# 964                                 The Grudge  2020      Nicolas Pesce
#
#                  writer               producer       main_actor_1  \
# ...

# %%
num_of_movies = merged.groupby('main_actor_1').count().sort_values('title', ascending=False)['title']
total_revenue1 = merged.groupby('main_actor_1').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue1['Number of movies'] = num_of_movies
total_revenue1.head(20)
pd.options.display.float_format = '${:,.1f}'.format

# %%
num_of_movies = merged.groupby('main_actor_2').count().sort_values('title', ascending=False)['title']
total_revenue2 = merged.groupby('main_actor_2').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue2['Number of movies'] = num_of_movies
total_revenue2.head(20)
# Out:
#                            Adjusted Domestic  Adjusted International  \
# main_actor_2
# Chris Evans                   $134,686,081.4          $224,646,383.2
# Robert Pattinson              $137,396,616.5          $210,240,605.0
# Josh Hutcherson               $167,279,311.0          $174,903,301.3
# Paul Walker                    $89,501,066.5          $227,528,658.6
# Elizabeth Olsen                $98,727,582.0          $172,709,242.0
# John Boyega                   $121,510,483.2          $144,582,036.3
# Sofia Boutella                 $90,275,692.1          $163,041,577.6
# Johnny Depp                    $69,659,621.4          $149,135,691.4
# Cameron Diaz                   $71,081,292.3          $145,353,999.9
# Anne Hathaway                  $63,271,783.5          $152,217,537.3
# Cate Blanchett                 $67,261,792.5          $123,642,715.1
# Bryce Dallas Howard            $71,235,949.0          $118,354,146.6
# ...

# %%
num_of_movies = merged.groupby('main_actor_3').count().sort_values('title', ascending=False)['title']
total_revenue3 = merged.groupby('main_actor_3').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue3['Number of movies'] = num_of_movies
total_revenue3
# Out:
#                     Adjusted Domestic  Adjusted International  \
# main_actor_3
# Dwayne Johnson         $103,061,569.7          $288,128,462.6
# Scarlett Johansson     $140,208,484.4          $220,039,110.0
# Taylor Lautner         $137,296,318.4          $210,115,002.5
# Liam Hemsworth         $155,452,256.0          $157,203,426.5
# Bryan Cranston         $111,399,648.9          $196,813,862.5
# ...                               ...                     ...
# Liv Tyler                   $62,266.0               $18,031.4
# Djimon Hounsou              $52,809.2               $24,304.4
# Ahna O'Reilly               $17,411.5               $36,840.5
# Richard Coyle                $2,621.8               $44,919.8
# Lane Garrison                $1,197.2                $5,969.0
#
#                     Adjusted Worldwide  Number of movies
# main_actor_3
# Dwayne Johnson          $391,190,032.2                 4
# Scarlett Johansson      $360,247,594.4                 5
# ...

# %%
num_of_movies = merged.groupby('main_actor_4').count().sort_values('title', ascending=False)['title']
total_revenue4 = merged.groupby('main_actor_4').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenue4['Number of movies'] = num_of_movies
total_revenue4
# Out:
#                   Adjusted Domestic  Adjusted International  \
# main_actor_4
# Ken Watanabe         $155,180,758.1          $277,231,600.3
# Russell Crowe         $90,275,692.1          $163,041,577.6
# Don Cheadle          $104,353,872.2          $147,822,698.4
# Domhnall Gleeson     $100,948,811.0          $133,316,660.7
# Jeremy Renner         $98,551,918.1          $128,158,736.2
# ...                             ...                     ...
# Russell Brand             $52,809.2               $24,304.4
# Miquel Fernández          $17,411.5               $36,840.5
# Heather Graham             $2,621.8               $44,919.8
# Gina Gershon              $26,198.2                $1,570.2
# Tara Holt                  $1,197.2                $5,969.0
#
#                   Adjusted Worldwide  Number of movies
# main_actor_4
# Ken Watanabe          $432,412,358.4                 4
# Russell Crowe         $253,317,269.7                 2
# ...

# %%
# merge1 = pd.merge(total_revenue1, total_revenue2, left_index = True)
# merge1
add1 = total_revenue1.add(total_revenue2, fill_value=0)
add2 = add1.add(total_revenue3, fill_value=0) 
add3 = add2.add(total_revenue4, fill_value=0)
ww = add3.sort_values('Adjusted Worldwide', ascending = False).head(10)
bar_chart= ww.plot.bar(y=['Adjusted Domestic','Adjusted International', 'Adjusted Worldwide'])
plt.tight_layout()
plt.title("Top Grossing Actors since 2010")
plt.xlabel("Actor/Actress")
plt.ylabel("Revenue in USD")
plt.legend(loc = 'best')
bar_chart.yaxis.set_major_formatter('${x:1,.2f}')

plt.savefig('../PNG Files/top_actors.png', format = 'png', bbox_inches='tight')
plt.show()

# %%
num_of_movies = merged.groupby('director').count().sort_values('title', ascending=False)['title']
total_revenued = merged.groupby('director').sum().sort_values('Adjusted Worldwide', ascending=False)[['Adjusted Domestic','Adjusted International','Adjusted Worldwide']]
total_revenued['Number of movies'] = num_of_movies
total_revenued.head(20)
# Out:
#                    Adjusted Domestic  Adjusted International  \
# director
# Christopher Nolan     $142,153,801.3          $248,650,503.7
# Gareth Edwards        $141,105,552.8          $215,206,791.9
# Joss Whedon           $122,347,056.4          $201,351,160.1
# Michael Bay            $92,472,758.8          $226,943,248.9
# Bill Condon           $110,965,747.1          $180,878,488.1
# J.J. Abrams           $133,667,905.2          $153,638,238.4
# Tim Burton             $86,575,768.9          $178,026,792.1
# Alex Kurtzman          $91,892,213.2          $163,057,717.5
# Francis Lawrence      $112,623,558.7          $131,872,224.0
# Jon Favreau           $108,954,885.8          $129,709,277.8
# James Wan              $74,538,495.6          $159,318,591.5
# Sam Mendes             $59,165,827.3          $167,888,095.7
# Mike Mitchell          $77,623,166.0          $144,524,471.0
# Ridley Scott           $70,101,174.8          $149,161,737.3
# ...

# %%
dw = total_revenued.sort_values('Adjusted Worldwide', ascending = False).head(10)
bar_chart = dw.plot.bar(y=['Adjusted Domestic','Adjusted International', 'Adjusted Worldwide'])
plt.tight_layout()
plt.title("Top Grossing Directors since 2010")
plt.xlabel("Director")
plt.ylabel("Revenue in USD")
plt.legend(loc = 'best')
bar_chart.yaxis.set_major_formatter('${x:1,.2f}')
plt.savefig('../PNG Files/top_directors.png', format = 'png', bbox_inches='tight')
plt.show()
