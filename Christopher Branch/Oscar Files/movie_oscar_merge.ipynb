# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path1 = "movies_clean.csv"
path2 = "the_oscar_award (version 1).csv"
moviesdf = pd.read_csv(path1)
oscardf = pd.read_csv(path2)
moviesdf = moviesdf.rename(columns={"name":"film", "year":"year_film"})
merge = pd.merge(moviesdf, oscardf, on=["film", "year_film"])
merge
# Out:
#                            film rating      genre  year_film  score  \
# 0                   Raging Bull      R  Biography       1980    8.2
# 1               Ordinary People      R      Drama       1980    7.7
# 2               Ordinary People      R      Drama       1980    7.7
# 3         Coal Miner's Daughter     PG  Biography       1980    7.5
# 4             Melvin and Howard      R     Comedy       1980    6.8
# ..                          ...    ...        ...        ...    ...
# 195  If Beale Street Could Talk      R      Drama       2018    7.1
# 196                       Joker      R      Crime       2019    8.4
# 197                    Parasite      R     Comedy       2019    8.6
# 198              Marriage Story      R     Comedy       2019    7.9
# 199                 Toy Story 4      G  Animation       2019    7.7
#
#           budget         gross  runtime  year_ceremony  ceremony  \
# 0     18000000.0  2.340243e+07    129.0           1981        53
# 1      6000000.0  5.476692e+07    124.0           1981        53
# 2      6000000.0  5.476692e+07    124.0           1981        53
# 3            NaN  6.718279e+07    124.0           1981        53
# 4      7000000.0  4.309490e+06     95.0           1981        53
# ..           ...           ...      ...            ...       ...
# 195   12000000.0  2.059657e+07    119.0           2019        91
# 196   55000000.0  1.074427e+09    122.0           2020        92
# 197   11400000.0  2.589081e+08    132.0           2020        92
# 198   18600000.0  3.336860e+05    137.0           2020        92
# 199  200000000.0  1.073395e+09    100.0           2020        92
#
#                          category                                        name  \
# 0         ACTOR IN A LEADING ROLE                              Robert De Niro
# 1      ACTOR IN A SUPPORTING ROLE                              Timothy Hutton
# 2                    BEST PICTURE                 Ronald L. Schwary, Producer
# 3       ACTRESS IN A LEADING ROLE                                Sissy Spacek
# 4    ACTRESS IN A SUPPORTING ROLE                            Mary Steenburgen
# ..                            ...                                         ...
# 195  ACTRESS IN A SUPPORTING ROLE                                 Regina King
# 196       ACTOR IN A LEADING ROLE                             Joaquin Phoenix
# 197                  BEST PICTURE     Kwak Sin Ae and Bong Joon Ho, Producers
# 198  ACTRESS IN A SUPPORTING ROLE                                  Laura Dern
# 199         ANIMATED FEATURE FILM  Josh Cooley, Mark Nielsen and Jonas Rivera
#
#      winner
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 195    True
# 196    True
# 197    True
# 198    True
# 199    True
#
# [200 rows x 13 columns]

# %%
just_actors = merge.loc[(merge['year_film'] >=2010)&((merge['category'] == 'ACTOR IN A LEADING ROLE') | (merge['category'] == 'ACTRESS IN A LEADING ROLE')), :]
just_actors
# Out:
#                          film rating      genre  year_film  score  \
# 145                Black Swan      R      Drama       2010    8.0
# 147         The King's Speech      R  Biography       2010    8.0
# 153                The Artist  PG-13     Comedy       2011    7.9
# 155             The Iron Lady  PG-13  Biography       2011    6.4
# 159   Silver Linings Playbook      R     Comedy       2012    7.7
# 160                   Lincoln  PG-13  Biography       2012    7.3
# 165        Dallas Buyers Club      R  Biography       2013    8.0
# 167              Blue Jasmine  PG-13     Comedy       2013    7.3
# 172  The Theory of Everything  PG-13  Biography       2014    7.7
# 173               Still Alice  PG-13      Drama       2014    7.5
# 174              The Revenant      R     Action       2015    8.0
# 175                      Room      R      Drama       2015    8.1
# 180                La La Land  PG-13     Comedy       2016    8.0
# 184     Manchester by the Sea      R      Drama       2016    7.8
# 186              Darkest Hour  PG-13  Biography       2017    7.4
# 190         Bohemian Rhapsody  PG-13  Biography       2018    7.9
# 194             The Favourite      R  Biography       2018    7.5
# 196                     Joker      R      Crime       2019    8.4
#
#           budget         gross  runtime  year_ceremony  ceremony  \
# 145   13000000.0  3.293980e+08    108.0           2011        83
# 147   15000000.0  4.273743e+08    118.0           2011        83
# 153   15000000.0  1.334329e+08    100.0           2012        84
# 155   13000000.0  1.158907e+08    105.0           2012        84
# 159   21000000.0  2.364125e+08    122.0           2013        85
# 160   65000000.0  2.752934e+08    150.0           2013        85
# 165    5000000.0  5.573659e+07    117.0           2014        86
# 167   18000000.0  9.910480e+07     98.0           2014        86
# 172   15000000.0  1.237267e+08    123.0           2015        87
# 173    5000000.0  4.477920e+07    101.0           2015        87
# 174  135000000.0  5.329505e+08    156.0           2016        88
# 175   13000000.0  3.540176e+07    118.0           2016        88
# 180   30000000.0  4.489069e+08    128.0           2017        89
# 184    9000000.0  7.898815e+07    137.0           2017        89
# 186   30000000.0  1.508473e+08    125.0           2018        90
# 190   52000000.0  9.119026e+08    134.0           2019        91
# 194   15000000.0  9.591871e+07    119.0           2019        91
# 196   55000000.0  1.074427e+09    122.0           2020        92
#
#                       category                 name  winner
# 145  ACTRESS IN A LEADING ROLE      Natalie Portman    True
# 147    ACTOR IN A LEADING ROLE          Colin Firth    True
# 153    ACTOR IN A LEADING ROLE        Jean Dujardin    True
# 155  ACTRESS IN A LEADING ROLE         Meryl Streep    True
# 159  ACTRESS IN A LEADING ROLE    Jennifer Lawrence    True
# 160    ACTOR IN A LEADING ROLE     Daniel Day-Lewis    True
# 165    ACTOR IN A LEADING ROLE  Matthew McConaughey    True
# 167  ACTRESS IN A LEADING ROLE       Cate Blanchett    True
# 172    ACTOR IN A LEADING ROLE       Eddie Redmayne    True
# 173  ACTRESS IN A LEADING ROLE       Julianne Moore    True
# 174    ACTOR IN A LEADING ROLE    Leonardo DiCaprio    True
# 175  ACTRESS IN A LEADING ROLE          Brie Larson    True
# 180  ACTRESS IN A LEADING ROLE           Emma Stone    True
# 184    ACTOR IN A LEADING ROLE        Casey Affleck    True
# 186    ACTOR IN A LEADING ROLE          Gary Oldman    True
# 190    ACTOR IN A LEADING ROLE           Rami Malek    True
# 194  ACTRESS IN A LEADING ROLE        Olivia Colman    True
# 196    ACTOR IN A LEADING ROLE      Joaquin Phoenix    True

# %%
plt.bar(just_actors['name'], just_actors['gross'])
plt.xticks(rotation = 'vertical')
plt.ylabel('Revenue in Billions (USD)')
plt.xlabel("Best Actor/Actress since 2010")
plt.title("Oscar Winning Actors vs Revenue")
plt.savefig('../PNG Files/oscar_winning_actors.png', format = 'png', bbox_inches='tight')
plt.show()

# %%
oscar_path = 'the_oscar_award(version 2).csv'
oscar_nominees = pd.read_csv(oscar_path)
new_merge = pd.merge(moviesdf, oscar_nominees , on=["film", "year_film"])

best_pictures = new_merge.loc[(new_merge['year_film'] ==2017)&((new_merge['category'] == 'BEST PICTURE')), :].sort_values('gross', ascending = False).head(5)
best_pictures
explode = [0,0,.1,0,0]
best_pictures.set_index('film').plot.pie(y='gross', legend=False, explode = explode, startangle=90, shadow=True,autopct='%1.2f%%')
plt.axis('equal')
plt.ylabel('Percentage of Revenue')
plt.title("2018 Oscars Top 5 Grossing Best Picture Nominees")
plt.savefig('../PNG Files/2018_Oscars.png', format = 'png', bbox_inches='tight')
plt.show()

# %%
best_pictures = new_merge.loc[(new_merge['year_film'] ==2018)&((new_merge['category'] == 'BEST PICTURE')), :].sort_values('gross', ascending = False).head(5)
best_pictures
explode = [0,.1,0,0,0]
best_pictures.set_index('film').plot.pie(y='gross', legend=False, explode = explode, startangle=90, shadow=True,autopct='%1.2f%%')
plt.axis('equal')
plt.ylabel('Percentage of Revenue')
plt.title("2019 Oscars Top 5 Grossing Best Picture Nominees")
plt.show()

# %%
best_pictures = new_merge.loc[(new_merge['year_film'] ==2019)&((new_merge['category'] == 'BEST PICTURE')), :].sort_values('gross', ascending = False).head(5)
best_pictures
explode = [0,0,.1,0,0]
best_pictures.set_index('film').plot.pie(y='gross', legend=False, explode = explode, startangle=90, shadow=True,autopct='%1.2f%%')
plt.axis('equal')
plt.ylabel('Percentage of Revenue')
plt.title("2020 Oscars Top 5 Grossing Best Picture Nominees")
plt.show()
